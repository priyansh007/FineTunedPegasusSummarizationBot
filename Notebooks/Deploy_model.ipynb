# %%
# !pip install huggingface_hub
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 236.8/236.8 kB 4.7 MB/s eta 0:00:00
# ...

# %%
from huggingface_hub import notebook_login, HfApi
import os
import nltk
from nltk import word_tokenize
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
api = HfApi()

# %%
notebook_login()

# %%
#Run if you want to create new repo
#api.create_repo(repo_id="NewsPegasusModel")
# Out:
# RepoUrl('https://huggingface.co/pzalavad/NewsPegasusModel', endpoint='https://huggingface.co', repo_type='model', repo_id='pzalavad/NewsPegasusModel')

# %%
folder_path = '/content/drive/MyDrive/NewsNebula/model'

# %%
files = os.listdir(folder_path)
for file_name in files:
  api.upload_file(
      path_or_fileobj=os.path.join(folder_path, file_name),
      path_in_repo=file_name,
      repo_id="pzalavad/NewsPegasusModel",
      repo_type="model",
  )
# Out:
# Upload 1 LFS files:   0%|          | 0/1 [00:00<?, ?it/s]
# pytorch_model.bin:   0%|          | 0.00/2.28G [00:00<?, ?B/s]
# Upload 1 LFS files:   0%|          | 0/1 [00:00<?, ?it/s]
# training_args.bin:   0%|          | 0.00/3.90k [00:00<?, ?B/s]
# Upload 1 LFS files:   0%|          | 0/1 [00:00<?, ?it/s]
# spiece.model:   0%|          | 0.00/1.91M [00:00<?, ?B/s]

# %% [markdown]
# ## Test deployed model

# %%
import requests

API_URL = "https://api-inference.huggingface.co/models/pzalavad/NewsPegasusModel"
headers = {"Authorization": "Bearer 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"}

def query(payload):
	response = requests.post(API_URL, headers=headers, json=payload)
	return response.json()


def Summarize_models(path):
  for filename in os.listdir(path):
    if filename.endswith(".txt"):
        file_path = os.path.join(path, filename)
        with open(file_path, "r", encoding="utf-8") as file:
            text = file.read()
            words = word_tokenize(text)
            length = len(words)
            if length>500:
              words = words[:500]
            length = len(words)
            text = ' '.join(words)
            output = query({
	                    "inputs": text,
                     })
            print(output)

# %%
Summarize_models('/content/drive/MyDrive/NewsNebula/tests')
# Out:
# [{'generated_text': 'russian-controlled regions of eastern and southern lawmakers announced plans to start voting this week to become integral parts of russia .<n>Kremlin-backed efforts to swallow up four regions could set the stage for moscow to escalate the war following ukrainian successes on the battlefield .<n>The scheduling of referendums starting in the luhansk , kherson and partly russian-controlled zaporizhzhia and donetsk regions came after a close ally of russian president imir putin said the votes are needed and as moscow is losing ground in the invasion it began nearly seven months ago, increasing pressure on'}]
# ...
